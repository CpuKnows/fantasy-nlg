# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import time
import csv
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, SimpleRNN
from keras.layers.wrappers import TimeDistributed
# Out:
# Using TensorFlow backend.

# %%
DATA_DIR = '../../../analysis/data/nbmodel_templates.csv'
BATCH_SIZE = 100
HIDDEN_DIM = 100
SEQ_LENGTH = 50
WEIGHTS = ''

GENERATE_LENGTH = 100
LAYER_NUM = 2

# %%
reports = []

with open(DATA_DIR, encoding='utf-8-sig') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            reports.append(row[3].replace('"', '').replace("[", '').replace(']', ''))
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are report, report_chunks, template_chunks, templates
# Processed 1953 lines.

# %%
data = ' '.join(reports).split(' ')
len(data)
# Out:
# 40864

# %%
data[:10]
# Out:
# ['${player_name}',
#  'caught',
#  '${receptions}',
#  'passes',
#  'for',
#  '${rec_yards}',
#  'yards',
#  'and',
#  'a',
#  'touchdown']

# %%
# method for preparing the training data
def load_data(data, seq_length):
    chunks = list(set(data))
    VOCAB_SIZE = len(chunks)

    print('Data length: {} chunks'.format(len(data)))
    print('Vocabulary size: {} chunks'.format(VOCAB_SIZE))

    ix_to_chunk = {ix:chunk for ix, chunk in enumerate(chunks)}
    chunk_to_ix = {chunk:ix for ix, chunk in enumerate(chunks)}
    
    num_seq = int(np.floor((len(data) - 1) / seq_length))

    X = np.zeros((num_seq, seq_length, VOCAB_SIZE))
    y = np.zeros((num_seq, seq_length, VOCAB_SIZE))
    for i in range(0, num_seq):
        X_sequence = data[i*seq_length:(i+1)*seq_length]
        X_sequence_ix = [chunk_to_ix[value] for value in X_sequence]
        input_sequence = np.zeros((seq_length, VOCAB_SIZE))
        for j in range(seq_length):
            input_sequence[j][X_sequence_ix[j]] = 1.
            X[i] = input_sequence

        y_sequence = data[i*seq_length+1:(i+1)*seq_length+1]
        y_sequence_ix = [chunk_to_ix[value] for value in y_sequence]
        target_sequence = np.zeros((seq_length, VOCAB_SIZE))
        for j in range(seq_length):
            target_sequence[j][y_sequence_ix[j]] = 1.
            y[i] = target_sequence
    return X, y, VOCAB_SIZE, ix_to_chunk

# %%
# Creating training data
X, y, VOCAB_SIZE, ix_to_chunk = load_data(data, SEQ_LENGTH)
# Out:
# Data length: 40864 chunks
# Vocabulary size: 550 chunks

# %%
# method for generating text
def generate_text(model, length, vocab_size, ix_to_chunk):
    # starting with random chunk
    ix = [np.random.randint(vocab_size)]
    y_chunk = [ix_to_chunk[ix[-1]]]
    X = np.zeros((1, length, vocab_size))
    for i in range(length):
        # appending the last predicted chunk to sequence
        X[0, i, :][ix[-1]] = 1
        print(ix_to_chunk[ix[-1]], end=" ")
        ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
        y_chunk.append(ix_to_chunk[ix[-1]])
    return ('').join(y_chunk)

# %%
# x = np.zeros((1, GENERATE_LENGTH, VOCAB_SIZE))

# %%
# model.predict(x[:, :5, :])

# %%
# Creating and compiling the Network
model = Sequential()
model.add(LSTM(HIDDEN_DIM, input_shape=(None, VOCAB_SIZE), return_sequences=True))
for i in range(LAYER_NUM - 1):
  model.add(LSTM(HIDDEN_DIM, return_sequences=True))
model.add(TimeDistributed(Dense(VOCAB_SIZE)))
model.add(Activation('softmax'))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")

# %%
# Generate some sample before training to know how bad it is!
generate_text(model, GENERATE_LENGTH, VOCAB_SIZE, ix_to_chunk)
# Out:
# single failed failed London, 304 304 32 that that 32 racked racked chipped chipped at at receiving receiving handled McCarthy. McCarthy. McCarthy. McCarthy. McCarthy. McCarthy. potential carries carries ${team_score}-${opp_score}, ${team_score}-${opp_score}, pulled pulled field field grab grab pulled pulled passes passes passes leaving leaving leaving Thanksgiving. Thanksgiving. soaked soaked secured secured secured shoving before before before third third third 38 38 38 38 38 38 pass pass pass pass offense. offense. offense. offense. offense. measure Achilles' string string string efficiently efficiently efficiently efficiently Losing Losing upset ${rush_attempts} ${rush_attempts} ${rush_attempts} ${rush_attempts} ${rush_attempts} catches catches ${rush_attempts} ${rush_attempts} ${rush_attempts} catches catches ${rush_attempts} ${rush_attempts} starting
# "singlefailedfailedLondon,30430432thatthat32rackedrackedchippedchippedatatreceivingreceivinghandledMcCarthy.McCarthy.McCarthy.McCarthy.McCarthy.McCarthy.potentialcarriescarries${team_score}-${opp_score},${team_score}-${opp_score},pulledpulledfieldfieldgrabgrabpulledpulledpassespassespassesleavingleavingleavingThanksgiving.Thanksgiving.soakedsoakedsecuredsecuredsecuredshovingbeforebeforebeforethirdthirdthird383838383838passpasspasspassoffense.offense.offense.offense.offense.measureAchilles'stringstringstringefficientlyefficientlyefficientlyefficientlyLosingLosingupset${rush_attempts}${rush_attempts}${rush_attempts}${rush_attempts}${rush_attempts}catchescatches${rush_attempts}${rush_attempts}${rush_attempts}catchescatches${rush_attempts}${rush_attempts}startingversus"

# %%
# Training if there is no trained weights specified
if not WEIGHTS == '':
  model.load_weights(WEIGHTS)
  nb_epoch = int(WEIGHTS[WEIGHTS.rfind('_') + 1:WEIGHTS.find('.')])
else:
  nb_epoch = 0

if WEIGHTS == '':
  while True:
    print('\n\nEpoch: {}\n'.format(nb_epoch))
    model.fit(X, y, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
    nb_epoch += 1
    
    if nb_epoch % 10 == 0:
        generate_text(model, GENERATE_LENGTH, VOCAB_SIZE, ix_to_chunk)
        model.save_weights('checkpoint_unigram_layer_{}_hidden_{}_epoch_{}.hdf5'.format(LAYER_NUM, HIDDEN_DIM, nb_epoch))
# Else, loading the trained weights and perform generation only
elif WEIGHTS == '':
  # Loading the trained weights
  model.load_weights(WEIGHTS)
  generate_text(model, GENERATE_LENGTH, VOCAB_SIZE, ix_to_char)
  print('\n\n')
else:
  print('\n\nNothing to do!')
# Out:
# Epoch: 0
# c:\program files (x86)\microsoft visual studio\shared\python36_64\lib\site-packages\ipykernel_launcher.py:11: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   # This is added back by InteractiveShellApp.init_path()
# Epoch 1/1
# 2043/2043 [==============================] - 5s 3ms/step - loss: 4.9929
#
#
# Epoch: 1
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 950us/step - loss: 4.1483
#
#
# Epoch: 2
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 928us/step - loss: 4.0448
#
#
# Epoch: 3
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 939us/step - loss: 3.9902
#
#
# Epoch: 4
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 932us/step - loss: 3.9546
#
#
# Epoch: 5
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 911us/step - loss: 3.9342 0s - loss:
#
#
# Epoch: 6
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 951us/step - loss: 3.9169
#
#
# Epoch: 7
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 908us/step - loss: 3.9001
#
#
# Epoch: 8
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 920us/step - loss: 3.8874
#
#
# Epoch: 9
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 925us/step - loss: 3.8782
# 36 the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Epoch: 10
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 924us/step - loss: 3.8718
#
#
# Epoch: 11
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 996us/step - loss: 3.8690
#
#
# Epoch: 12
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 1ms/step - loss: 3.8669
#
#
# Epoch: 13
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 905us/step - loss: 3.8660
#
#
# Epoch: 14
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 918us/step - loss: 3.8643
#
#
# Epoch: 15
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 1ms/step - loss: 3.8605
#
#
# Epoch: 16
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 886us/step - loss: 3.8505
#
#
# Epoch: 17
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 932us/step - loss: 3.8343
#
#
# Epoch: 18
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 1ms/step - loss: 3.8118
#
#
# Epoch: 19
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 983us/step - loss: 3.7703
# pickup the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Epoch: 20
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 944us/step - loss: 3.7275
#
#
# Epoch: 21
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 907us/step - loss: 3.6508
#
#
# Epoch: 22
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 871us/step - loss: 3.5656
#
#
# Epoch: 23
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 927us/step - loss: 3.4268
#
#
# Epoch: 24
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 914us/step - loss: 3.3164 1
#
#
# Epoch: 25
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 900us/step - loss: 3.2168
#
#
# Epoch: 26
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 869us/step - loss: 3.1271
#
#
# Epoch: 27
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 885us/step - loss: 3.0527
#
#
# Epoch: 28
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 884us/step - loss: 2.9697
#
#
# Epoch: 29
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 889us/step - loss: 2.9075
# fibula the the the the the ${opp}. ${player_name} ${receptions} of for for yards in in week the the ${opp}. ${player_name} ${receptions} of for for yards in in week the the ${opp}. ${player_name} ${receptions} of for for yards in in week the the ${opp}. ${player_name} ${receptions} of for for yards in in week the the ${opp}. ${player_name} ${receptions} of for for yards in in week the the ${opp}. ${player_name} ${receptions} of for for yards in in week the the ${opp}. ${player_name} ${receptions} of for for yards in in week the the ${opp}. ${player_name} ${receptions} of for for yards in in week
#
# Epoch: 30
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 901us/step - loss: 2.8418
#
#
# Epoch: 31
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 888us/step - loss: 2.7810
#
#
# Epoch: 32
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 888us/step - loss: 2.7306
#
#
# Epoch: 33
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 857us/step - loss: 2.6688
#
#
# Epoch: 34
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 850us/step - loss: 2.6168
#
#
# Epoch: 35
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 868us/step - loss: 2.5494
#
#
# Epoch: 36
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 910us/step - loss: 2.5015
#
#
# Epoch: 37
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 891us/step - loss: 2.4401
#
#
# Epoch: 38
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 897us/step - loss: 2.3955
#
#
# Epoch: 39
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 855us/step - loss: 2.3389
# relief in the ${week} the ${opp}. ${player_name} ${receptions} of for yards yards in the ${week} ${week} the ${opp}. ${player_name} ${receptions} of for yards yards in the ${week} ${week} the ${opp}. ${player_name} ${receptions} of for yards yards in the ${week} ${week} the ${opp}. ${player_name} ${receptions} of for yards yards in the ${week} ${week} the ${opp}. ${player_name} ${receptions} of for yards yards in the ${week} ${week} the ${opp}. ${player_name} ${receptions} of for yards yards in the ${week} ${week} the ${opp}. ${player_name} ${receptions} of for yards yards in the ${week} ${week} the ${opp}. ${player_name} ${receptions} of for yards yards in the ${week} ${week}
#
# Epoch: 40
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 897us/step - loss: 2.2738
#
#
# Epoch: 41
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 855us/step - loss: 2.2164
#
#
# Epoch: 42
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 849us/step - loss: 2.1703
#
#
# Epoch: 43
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 869us/step - loss: 2.1150
#
#
# Epoch: 44
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 899us/step - loss: 2.0706
#
#
# Epoch: 45
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 861us/step - loss: 2.0054 0s - loss: 2.006
#
#
# Epoch: 46
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 857us/step - loss: 1.9739
#
#
# Epoch: 47
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 868us/step - loss: 1.9187
#
#
# Epoch: 48
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 867us/step - loss: 1.8806
#
#
# Epoch: 49
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 850us/step - loss: 1.8353
# patella in week the the ${opp}. ${player_name} ${receptions} of for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for yards in week the the ${opp}. ${player_name} ${receptions} ${rec_targets} for
#
# Epoch: 50
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 878us/step - loss: 1.8005
#
#
# Epoch: 51
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 858us/step - loss: 1.7652
#
#
# Epoch: 52
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 859us/step - loss: 1.7324
#
#
# Epoch: 53
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 862us/step - loss: 1.6998
#
#
# Epoch: 54
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 853us/step - loss: 1.6674
# Epoch: 55
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 860us/step - loss: 1.6434
#
#
# Epoch: 56
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 876us/step - loss: 1.6115
#
#
# Epoch: 57
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 926us/step - loss: 1.5887
#
#
# Epoch: 58
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 947us/step - loss: 1.5603
#
#
# Epoch: 59
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 915us/step - loss: 1.5385
# City's in week the ${opp}. completed ${receptions} for yards and for on on in week the ${player_name} ${receptions} ${rec_yards} ${rush_attempts} for and on on in week the ${player_name} ${receptions} ${rec_yards} ${rec_targets} ${rec_yards} a targets ${rec_yards} a targets ${rec_yards} the ${week} the ${opp}. completed ${receptions} for yards and for on on in week the ${opp}. completed ${receptions} for yards and for on on in week the ${opp}. completed ${receptions} for yards and for on on in week the ${opp}. completed ${receptions} for yards and for on on in week the ${opp}. completed ${receptions} for yards and for on on in week
#
# Epoch: 60
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 911us/step - loss: 1.5209
#
#
# Epoch: 61
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 897us/step - loss: 1.4967
#
#
# Epoch: 62
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 849us/step - loss: 1.4746
#
#
# Epoch: 63
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 876us/step - loss: 1.4610
#
#
# Epoch: 64
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 860us/step - loss: 1.4359
#
#
# Epoch: 65
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 849us/step - loss: 1.4256
#
#
# Epoch: 66
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 865us/step - loss: 1.4088
#
#
# Epoch: 67
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 870us/step - loss: 1.3984
#
#
# Epoch: 68
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 872us/step - loss: 1.3754
#
#
# Epoch: 69
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 873us/step - loss: 1.3669
# attempts. ${receptions} targets yards in week the ${week} the ${opp}. ${player_name} ${receptions} targets yards yards ${team}' week the the loss the ${opp}. ${player_name} ${receptions} targets yards yards targets yards ${team}' week the the loss the ${opp}. ${player_name} ${receptions} targets yards yards targets yards ${team}' week the the loss the ${opp}. ${player_name} ${receptions} targets yards yards targets yards ${team}' week the the loss the ${opp}. ${player_name} ${receptions} targets yards yards targets yards ${team}' week the the loss the ${opp}. ${player_name} ${receptions} targets yards yards targets yards ${team}' week the the loss the ${opp}. ${player_name} ${receptions} targets yards yards targets yards ${team}'
#
# Epoch: 70
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 894us/step - loss: 1.3542
#
#
# Epoch: 71
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 874us/step - loss: 1.3402
#
#
# Epoch: 72
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 894us/step - loss: 1.3282
#
#
# Epoch: 73
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 865us/step - loss: 1.3203
#
#
# Epoch: 74
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 909us/step - loss: 1.3083
#
#
# Epoch: 75
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 863us/step - loss: 1.3022
#
#
# Epoch: 76
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 877us/step - loss: 1.2901
#
#
# Epoch: 77
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 855us/step - loss: 1.2832
#
#
# Epoch: 78
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 881us/step - loss: 1.2695
#
#
# Epoch: 79
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 849us/step - loss: 1.2674
# win. ${pass_yards} and and in the ${week} the ${week} the the ${week} ${opp}. ${receptions} ${rec_yards} ${rush_attempts} ${rush_yards} ${rush_attempts} ${rush_yards} ${rush_attempts} ${receptions} ${rec_yards} yards ${team}' week the ${week} the ${opp}. ${receptions} ${rec_yards} ${rec_targets} ${rec_yards} ${rec_targets} targets yards ${team}' week the ${week} the ${opp}. ${receptions} ${rec_yards} ${rec_targets} targets yards targets yards ${team}' week the the the the ${week} the ${player_name} ${receptions} ${rec_yards} ${rec_targets} ${rec_yards} ${rec_targets} targets yards ${team}' week the the the loss ${opp}. ${receptions} ${rec_yards} ${rush_attempts} ${rush_yards} ${rush_attempts} ${rush_yards} ${rush_attempts} ${receptions} ${rec_yards} yards ${team}' week the ${week} the ${opp}. ${receptions} ${rec_yards} ${rec_targets} targets yards targets yards ${team}' week the the the
#
# Epoch: 80
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 906us/step - loss: 1.2558
#
#
# Epoch: 81
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 849us/step - loss: 1.2474
#
#
# Epoch: 82
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 960us/step - loss: 1.2404
#
#
# Epoch: 83
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 957us/step - loss: 1.2346
#
#
# Epoch: 84
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 900us/step - loss: 1.2247
#
#
# Epoch: 85
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 909us/step - loss: 1.2220
#
#
# Epoch: 86
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 907us/step - loss: 1.2144
#
#
# Epoch: 87
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 842us/step - loss: 1.2059
#
#
# Epoch: 88
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 869us/step - loss: 1.2010
#
#
# Epoch: 89
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 853us/step - loss: 1.1964
# heart-breaking in week the ${opp}. ${player_name} ${receptions} targets yards in week the ${player_name} ${player_name} ${receptions} targets yards in week the ${week} ${opp}. ${player_name} ${receptions} targets yards yards ${team}' ${week} the ${opp}. ${receptions} ${rec_yards} ${rec_targets} targets yards targets yards in week the ${week} the ${opp}. ${player_name} ${receptions} targets yards touchdown targets yards ${team}' week over ${opp}. ${receptions} ${rec_yards} ${rec_targets} targets yards targets yards in week the ${week} the ${opp}. ${player_name} ${receptions} targets yards touchdown ${team}' ${week} the ${week} ${opp}. ${player_name} ${receptions} targets yards yards touchdown ${team}' ${week} over ${player_name} ${receptions} targets yards targets yards ${team}' week the ${week} the ${opp}. ${receptions}
#
# Epoch: 90
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 888us/step - loss: 1.1883
#
#
# Epoch: 91
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 892us/step - loss: 1.1795
#
#
# Epoch: 92
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 862us/step - loss: 1.1764
#
#
# Epoch: 93
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 961us/step - loss: 1.1720
#
#
# Epoch: 94
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 929us/step - loss: 1.1678
#
#
# Epoch: 95
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 919us/step - loss: 1.1598
#
#
# Epoch: 96
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 883us/step - loss: 1.1564
#
#
# Epoch: 97
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 872us/step - loss: 1.1513
#
#
# Epoch: 98
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 885us/step - loss: 1.1467
#
#
# Epoch: 99
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 865us/step - loss: 1.1419
# ${game_dow} ${team}' ${week} over ${opp}. ${receptions} ${rec_yards} a rushed for ${rec_yards} a targets ${game_dow} week the ${week} ${opp}. ${receptions} ${rec_yards} a targets ${rec_yards} a targets ${rec_yards} the ${week} the ${week} the ${week} the rushed for yard a targets yards touchdown targets for and for in a week the the the ${opp}. ${receptions} ${rec_yards} a targets yards additional rushed for a a touchdown touchdown touchdown ${receptions} targets yards touchdown targets targets yards the ${game_dow} ${team}' week over ${opp}. ${receptions} ${rec_yards} ${player_name} ${receptions} targets yards ${rec_yards} ${rec_targets} ${rec_yards} the week the the the loss ${opp}. ${receptions} ${rec_yards} on ${rush_yards} a touchdown carries
#
# Epoch: 100
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 883us/step - loss: 1.1348
#
#
# Epoch: 101
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 866us/step - loss: 1.1316
#
#
# Epoch: 102
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 866us/step - loss: 1.1294
#
#
# Epoch: 103
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 857us/step - loss: 1.1242
#
#
# Epoch: 104
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 857us/step - loss: 1.1183 0s - los
#
#
# Epoch: 105
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 868us/step - loss: 1.1135
#
#
# Epoch: 106
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 893us/step - loss: 1.1103
#
#
# Epoch: 107
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 881us/step - loss: 1.1061
#
#
# Epoch: 108
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 891us/step - loss: 1.1054
#
#
# Epoch: 109
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 876us/step - loss: 1.0945 0s - loss: 1.099
# needed in week the ${opp}. ${player_name} ${receptions} targets yards touchdown ${team}' ${week} over ${player_name} ${receptions} targets yards carries targets ${rush_yards} week the ${player_name} ${receptions} targets yards targets yards carries ${receptions} targets yards ${team}' ${week} the ${player_name} ${receptions} ${rec_yards} ${rec_targets} targets yards targets yards ${team}' week over ${player_name} ${receptions} targets yards touchdown ${team}' ${week} over ${player_name} ${receptions} targets yards targets yards ${team}' week over ${player_name} ${receptions} targets yards touchdown targets yards week the ${player_name} ${receptions} ${rec_targets} targets yards ${team}' week the ${player_name} ${receptions} targets yards touchdown targets ${rush_yards} week the ${player_name} ${receptions} targets yards touchdown targets ${rush_yards} week the ${player_name} ${receptions}
#
# Epoch: 110
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 875us/step - loss: 1.0920
#
#
# Epoch: 111
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 924us/step - loss: 1.0898
#
#
# Epoch: 112
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 898us/step - loss: 1.0848
#
#
# Epoch: 113
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 892us/step - loss: 1.0803
#
#
# Epoch: 114
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 877us/step - loss: 1.0758
#
#
# Epoch: 115
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 884us/step - loss: 1.0731
#
#
# Epoch: 116
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 890us/step - loss: 1.0699
#
#
# Epoch: 117
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 960us/step - loss: 1.0657
#
#
# Epoch: 118
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 880us/step - loss: 1.0587
#
#
# Epoch: 119
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 855us/step - loss: 1.0604
# was in week the ${player_name} ${receptions} ${rec_yards} ${rec_targets} targets week the rushed in ${player_name} ${receptions} targets yards touchdown targets yards in week ${opp}. ${receptions} ${rec_targets} targets targets yards touchdown targets ${game_dow} week the ${week} the ${opp}. ${receptions} ${receptions} targets yards targets yards touchdown week the ${player_name} ${receptions} ${rec_targets} targets yards touchdown targets yards carries week ${opp}. ${receptions} ${rec_targets} targets targets yards in week the ${week} the ${opp}. ${receptions} ${receptions} targets yards targets yards carries week the ${player_name} ${receptions} ${rec_targets} targets yards targets yards touchdown week the ${player_name} ${receptions} ${rec_targets} targets yards touchdown targets yards carries week ${player_name} ${receptions} targets yards
#
# Epoch: 120
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 898us/step - loss: 1.0524
#
#
# Epoch: 121
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 867us/step - loss: 1.0511
#
#
# Epoch: 122
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 918us/step - loss: 1.0458
#
#
# Epoch: 123
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 865us/step - loss: 1.0439
#
#
# Epoch: 124
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 860us/step - loss: 1.0414
#
#
# Epoch: 125
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 883us/step - loss: 1.0358
#
#
# Epoch: 126
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 882us/step - loss: 1.0341
#
#
# Epoch: 127
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 894us/step - loss: 1.0309
#
#
# Epoch: 128
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 912us/step - loss: 1.0224
#
#
# Epoch: 129
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 914us/step - loss: 1.0248
# attempts in week the ${player_name} ${receptions} ${rec_yards} ${rec_targets} targets targets yards week ${opp}. ${receptions} targets yards carries lone for in week ${player_name} ${receptions} ${rec_targets} targets targets yards yards carries lone of for carries ${rec_targets} targets the week ${player_name} ${receptions} targets targets yards touchdown targets targets week the ${player_name} ${receptions} ${rec_targets} targets yards touchdown week the ${player_name} ${receptions} ${player_name} ${receptions} targets yards yards touchdown ${week} week ${opp}. ${receptions} ${player_name} ${receptions} targets yards touchdown targets targets in week the ${player_name} ${receptions} ${rec_targets} targets yards touchdown week ${opp}. ${receptions} ${rec_targets} targets target targets yards ${team}' week the ${player_name} ${receptions} ${rec_yards} ${rec_targets} targets yards
#
# Epoch: 130
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 960us/step - loss: 1.0162
#
#
# Epoch: 131
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 933us/step - loss: 1.0155
#
#
# Epoch: 132
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 911us/step - loss: 1.0105
#
#
# Epoch: 133
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 932us/step - loss: 1.0103
#
#
# Epoch: 134
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 964us/step - loss: 1.0046
#
#
# Epoch: 135
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 1ms/step - loss: 1.0033
#
#
# Epoch: 136
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 1ms/step - loss: 0.9994
#
#
# Epoch: 137
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 986us/step - loss: 0.9980
#
#
# Epoch: 138
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 929us/step - loss: 0.9897
#
#
# Epoch: 139
#
# Epoch 1/1
# 2043/2043 [==============================] - 2s 943us/step - loss: 0.9906
# Niners. for and on the week the to ${opp}. ${pass_completions} passes yards and of for for and on ${game_dow} ${team}' week the to ${opp}. ${rush_attempts} ${rush_attempts} ${rush_yards} ${rush_attempts} ${rush_yards} carries carries carries carries carries carries carries of of for while ${receptions} ${rec_yards} the ${team}' ${team}'s the the loss the rushed for for ${rec_targets} and on and and in week the completed ${pass_completions} passes yards
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-3d864fa90911> in <module>()
#      13
#      14     if nb_epoch % 10 == 0:
# ---> 15         generate_text(model, GENERATE_LENGTH, VOCAB_SIZE, ix_to_chunk)
#      16         model.save_weights('checkpoint_unigram_layer_{}_hidden_{}_epoch_{}.hdf5'.format(LAYER_NUM, HIDDEN_DIM, nb_epoch))
#      17 # Else, loading the trained weights and perform generation only
#
# <ipython-input-13-8c7670d8b07e> in generate_text(model, length, vocab_size, ix_to_chunk)
#       9         X[0, i, :][ix[-1]] = 1
#      10         print(ix_to_chunk[ix[-1]], end=" ")
# ---> 11         ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
#      12         y_chunk.append(ix_to_chunk[ix[-1]])
#      13     return ('').join(y_chunk)
#
# c:\program files (x86)\microsoft visual studio\shared\python36_64\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# c:\program files (x86)\microsoft visual studio\shared\python36_64\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# c:\program files (x86)\microsoft visual studio\shared\python36_64\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# c:\program files (x86)\microsoft visual studio\shared\python36_64\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# c:\program files (x86)\microsoft visual studio\shared\python36_64\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
generate_text(model, 200, VOCAB_SIZE, ix_to_chunk)
# Out:
# pulled through ${pass_attempts} ${pass_yards} yards, and ${pass_td} the week in the ${team}' loss the completed ${pass_completions} of for a yards yards ${game_dow} ${game_dow} ${week} win ${opp}. ${player_name} ${receptions} of for a yards touchdown touchdown ${rush_attempts} adding adding for another ${game_dow} touchdown ${game_dow} ${game_dow} ${week} ${player_name} completed of ${pass_attempts} for a a yards touchdown touchdown touchdown touchdowns in week the completed ${player_name} times for and and another in gain ${game_dow} ${game_dow} ${team}' week the completed ${player_name} ${receptions} the caught for touchdown ${rec_yards} ${rec_yards} ${game_dow} ${team}' ${game_dow} ${week} the completed ${player_name} times for and on ${game_dow} ${game_dow} ${game_dow} ${week} ${week} the completed ${player_name} passes for and for yard ${game_dow} gain ${game_dow} week the in the ${week} ${player_name} times yards ${team}' week the the ${team}' ${week} the completed ${player_name} of for for in yards ${game_dow} ${game_dow} ${game_dow} ${week} ${player_name} ${receptions} targets yard ${player_name} ${receptions} targets yards and ${game_dow} touchdown ${game_dow} ${game_dow} ${week} in the ${week} ${player_name} completed ${pass_attempts} passes yards and in week the caught for and and another in gain ${game_dow} ${team}' ${week} in the ${team}' ${game_dow} ${game_dow} Cowboys' ${game_dow} ${week} ${player_name} times yards ${team}' week ${player_name} targets ${team}'s ${player_name} catches for and on ${team}'s ${game_dow} ${game_dow} Cowboys' ${week} ${player_name} ${receptions} the
# "pulledthrough${pass_attempts}${pass_yards}yards,and${pass_td}theweekinthe${team}'lossthecompleted${pass_completions}offorayardsyards${game_dow}${game_dow}${week}win${opp}.${player_name}${receptions}offorayardstouchdowntouchdown${rush_attempts}addingaddingforanother${game_dow}touchdown${game_dow}${game_dow}${week}${player_name}completedof${pass_attempts}foraayardstouchdowntouchdowntouchdowntouchdownsinweekthecompleted${player_name}timesforandandanotheringain${game_dow}${game_dow}${team}'weekthecompleted${player_name}${receptions}thecaughtfortouchdown${rec_yards}${rec_yards}${game_dow}${team}'${game_dow}${week}thecompleted${player_name}timesforandon${game_dow}${game_dow}${game_dow}${week}${week}thecompleted${player_name}passesforandforyard${game_dow}gain${game_dow}weektheinthe${week}${player_name}timesyards${team}'weekthethe${team}'${week}thecompleted${player_name}offorforinyards${game_dow}${game_dow}${game_dow}${week}${player_name}${receptions}targetsyard${player_name}${receptions}targetsyardsand${game_dow}touchdown${game_dow}${game_dow}${week}inthe${week}${player_name}completed${pass_attempts}passesyardsandinweekthecaughtforandandanotheringain${game_dow}${team}'${week}inthe${team}'${game_dow}${game_dow}Cowboys'${game_dow}${week}${player_name}timesyards${team}'week${player_name}targets${team}'s${player_name}catchesforandon${team}'s${game_dow}${game_dow}Cowboys'${week}${player_name}${receptions}the${team}'"
